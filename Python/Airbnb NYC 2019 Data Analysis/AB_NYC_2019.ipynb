# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("AB_NYC_2019.csv")

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.shape
# Out:
# (48895, 16)

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df.size
# Out:
# 782320

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48890    False
# 48891    False
# 48892    False
# 48893    False
# 48894    False
# Length: 48895, dtype: bool

# %%
df.isnull().sum()/len(df)*100
# Out:
# id                                 0.000000
# name                               0.032723
# host_id                            0.000000
# host_name                          0.042949
# neighbourhood_group                0.000000
# neighbourhood                      0.000000
# latitude                           0.000000
# longitude                          0.000000
# room_type                          0.000000
# price                              0.000000
# minimum_nights                     0.000000
# number_of_reviews                  0.000000
# last_review                       20.558339
# reviews_per_month                 20.558339
# calculated_host_listings_count     0.000000
# availability_365                   0.000000
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
#Fill the missing null values of each column by the median value, except for the 'reviews_per_month' and last_review column.
df.fillna({'name':df['name'].mode()[0]}, inplace=True)

# %%
df.fillna({'host_name':df['host_name'].mode()[0]},inplace=True)

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
#Use mean method to replace the null values in "reviews_per_month"
df.fillna({'reviews_per_month':df['reviews_per_month'].mean()},inplace=True)

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
##explore ffill() and bfill() methods
df[df['last_review'].isnull()]
# Out:
#              id                                               name   host_id  \
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 19         7750                  Huge 2 BR Upper East  Cental Park     17985
# 26         8700  Magnifique Suite au N de Manhattan - vue Cloitres     26394
# 36        11452                        Clean and Quiet in Brooklyn      7355
# 38        11943                          Country space in the city     45445
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df.index = range(1,48896)

# %%
df
# Out:
#              id                                               name   host_id  \
# 1          2539                 Clean & quiet apt home by the park      2787
# 2          2595                              Skylit Midtown Castle      2845
# 3          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 4          3831                    Cozy Entire Floor of Brownstone      4869
# 5          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48891  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48892  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48893  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48894  36485609               43rd St. Time Square-cozy single bed  30985759
# 48895  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
##Sort the dataset by the 'price' column in descending order.
df.sort_values(["price"],ascending=False)
# Out:
#              id                                               name    host_id  \
# 9152    7003697                Furnished room in Astoria apartment   20582832
# 17693  13894339    Luxury 1 bedroom apt. -stunning Manhattan views    5143901
# 29239  22436899                                1-BR Lincoln Center   72390391
# 40434  31340283  2br - The Heart of NYC: Manhattans Lower East ...    4382127
# 12343   9528920                Quiet, Clean, Lit @ LES & Chinatown    3906464
# ...         ...                                                ...        ...
# 25779  20624541      Modern apartment in the heart of Williamsburg   10132166
# 25797  20639914       Cozy yet spacious private brownstone bedroom   86327101
# 25434  20333471      ★Hostel Style Room | Ideal Traveling Buddies★  131697576
# 26842  21291569  Coliving in Brooklyn! Modern design / Shared room  101970559
# 25796  20639792  Contemporary bedroom in brownstone with nice view   86327101
#
# ...

# %%
df.sort_values(by = ['neighbourhood','price'])
# Out:
#              id                                               name    host_id  \
# 22776  18442048                            Clean-N-Comfy Bronx Pad   25385574
# 33741  26744053                                       Private Room  200933726
# 1168     498120                              Hi Traveler.. welcome    2459648
# 38594  30348636         Quiet, serene Holiday getaway in the Bronx   20444114
# 45759  34941479                         Place to be Private room 2  263266237
# ...         ...                                                ...        ...
# 18437  14499123      Spacious  Home 15 Minutes Away From Manhattan   89523770
# 28484  22088100  Bright and Warm place -\nonly 17min to Central...  161351021
# 10442   7997433  30 Mins to Times Square -Javits Ctr! Awesome f...   42215969
# 29017  22328175    Big room with private bath - close to Manhattan  161351021
# 10132   7771170                           Creative Woodside Studio    8134104
#
# ...

# %%
#Select and display the rows where the 'price' is greater than $500 for woodside
df[(df['price'] > 500) & (df['neighbourhood'] == 'woodside')]
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %%
#select and display all listings from vailable Kensington and Midtown
df[(df['neighbourhood'] == 'Kensington') | (df['neighbourhood'] == 'Midtown')]
# Out:
#              id                                               name    host_id  \
# 1          2539                 Clean & quiet apt home by the park       2787
# 2          2595                              Skylit Midtown Castle       2845
# 233       59855                            One bedroom Apt. in NYC     288031
# 246       61509                Quiet, clean midtown apt w. elevato      23619
# 259       63546                     Large and Cozy Private Bedroom     308652
# ...         ...                                                ...        ...
# 48747  36416632         Nice studio 4 people next to Times Square.  266294029
# 48749  36417250                 US Open special 2-bed luxury condo  133288905
# 48756  36419291  Wyndham Midtown 45 New York City 1 Bedroom Deluxe  273812306
# 48831  36450318       LUXURY, PRIVATE APT ACROSS FROM EMPIRE STATE  151831356
# 48887  36483010                    Comfy 1 Bedroom in Midtown East  274311461
#
# ...

# %%
df[df['neighbourhood'].isin(['Kensington', 'Midtown'])]
# Out:
#              id                                               name    host_id  \
# 1          2539                 Clean & quiet apt home by the park       2787
# 2          2595                              Skylit Midtown Castle       2845
# 233       59855                            One bedroom Apt. in NYC     288031
# 246       61509                Quiet, clean midtown apt w. elevato      23619
# 259       63546                     Large and Cozy Private Bedroom     308652
# ...         ...                                                ...        ...
# 48747  36416632         Nice studio 4 people next to Times Square.  266294029
# 48749  36417250                 US Open special 2-bed luxury condo  133288905
# 48756  36419291  Wyndham Midtown 45 New York City 1 Bedroom Deluxe  273812306
# 48831  36450318       LUXURY, PRIVATE APT ACROSS FROM EMPIRE STATE  151831356
# 48887  36483010                    Comfy 1 Bedroom in Midtown East  274311461
#
# ...

# %%
## Calculate the price per night for each listing and create a new column 'price_per_night' in the DataFrame.
df['price_per_night'] = df['price']/df['minimum_nights']

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 1  2539                Clean & quiet apt home by the park     2787
# 2  2595                             Skylit Midtown Castle     2845
# 3  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 4  3831                   Cozy Entire Floor of Brownstone     4869
# 5  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 1         John            Brooklyn    Kensington  40.64749  -73.97237
# 2     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 3    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 4  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 5        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
## convert the last_review to datetime val
df['last_review'] = pd.to_datetime(df['last_review'])

# %%
df
# Out:
#              id                                               name   host_id  \
# 1          2539                 Clean & quiet apt home by the park      2787
# 2          2595                              Skylit Midtown Castle      2845
# 3          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 4          3831                    Cozy Entire Floor of Brownstone      4869
# 5          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48891  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48892  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48893  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48894  36485609               43rd St. Time Square-cozy single bed  30985759
# 48895  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 1 to 48895
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48895 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48895 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df['last_review'] = df['last_review'].ffill()

# %%
df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# price_per_night                   0
# dtype: int64

# %%
#Group the data by the 'neighbourhood_group' column and calculate the mean price for each group. identify the high price
df.groupby('neighbourhood_group')[['price','price_per_night']].mean()
# Out:
#                           price  price_per_night
# neighbourhood_group
# Bronx                 87.496792        50.703610
# Brooklyn             124.383207        57.428778
# Manhattan            196.875814        86.945981
# Queens                99.517649        55.307232
# Staten Island        114.812332        65.941963

# %%
df.groupby(['neighbourhood_group','neighbourhood'])[['price','price_per_night']].mean()
# Out:
#                                         price  price_per_night
# neighbourhood_group neighbourhood
# Bronx               Allerton        87.595238        51.761338
#                     Baychester      75.428571        39.511905
#                     Belmont         77.125000        50.551389
#                     Bronxdale       57.105263        32.937970
#                     Castle Hill     63.000000        27.833333
# ...                                       ...              ...
# Staten Island       Tottenville    144.857143        59.178571
#                     West Brighton   80.555556        45.928451
#                     Westerleigh     71.500000        27.166667
#                     Willowbrook    249.000000        62.250000
#                     Woodrow        700.000000       100.000000
#
# [221 rows x 2 columns]

# %%
#calculate min,avg,max,mean for the price of each neighbourhood_group
df.groupby('neighbourhood_group')['price'].agg(['min','max','mean','count'])
# Out:
#                      min    max        mean  count
# neighbourhood_group
# Bronx                  0   2500   87.496792   1091
# Brooklyn               0  10000  124.383207  20104
# Manhattan              0  10000  196.875814  21661
# Queens                10  10000   99.517649   5666
# Staten Island         13   5000  114.812332    373

# %%
#Count the number of listings in each neighbourhood group.
df['neighbourhood_group'].value_counts()
# Out:
# neighbourhood_group
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: count, dtype: int64

# %%
df.groupby('neighbourhood_group').size().sort_values(ascending=False)
# Out:
# neighbourhood_group
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# dtype: int64

# %%
## creat pivot_table that displays number of listing fr each neighbourhood_group for diff room types
df.pivot_table(index='neighbourhood_group',columns='room_type',values='id',aggfunc='count')
# Out:
# room_type            Entire home/apt  Private room  Shared room
# neighbourhood_group
# Bronx                            379           652           60
# Brooklyn                        9559         10132          413
# Manhattan                      13199          7982          480
# Queens                          2096          3372          198
# Staten Island                    176           188            9

# %%
## fetch the avg prices for each neighbourhood grp and for each room type
df.pivot_table(index='room_type',columns='neighbourhood_group',values='price',aggfunc='mean')
# Out:
# neighbourhood_group       Bronx    Brooklyn   Manhattan      Queens  \
# room_type
# Entire home/apt      127.506596  178.327545  249.239109  147.050573
# Private room          66.788344   76.500099  116.776622   71.762456
# Shared room           59.800000   50.527845   88.977083   69.020202
#
# neighbourhood_group  Staten Island
# room_type
# Entire home/apt         173.846591
# Private room             62.292553
# Shared room              57.444444

# %% [markdown]
# ## Data visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
##create a line chart as a simple data
x = [1,2,3,4,5]
y = [i*i for i in x]
y
# Out:
# [1, 4, 9, 16, 25]

# %%
plt.figure(figsize= (8,4))
plt.plot(x,y,c= "red")
plt.title("Line chart for X and Y")
plt.xlabel("X values")
plt.ylabel("Y values")
plt.show()

# %%
## compare measures for different categories: bar plot
subjects = ['python','sql','power bi','excel']
marks = [60,70,90,75]

# %%
plt.bar(subjects,marks,color = ['red','green','yellow','blue'])
plt.show()

# %%
plt.barh(subjects,marks,color = ['red','green','yellow','blue'])
plt.show()

# %%
sns.countplot(data = df, x='neighbourhood_group')
plt.show()
